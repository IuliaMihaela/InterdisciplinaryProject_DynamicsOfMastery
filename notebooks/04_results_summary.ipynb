# %% [markdown]
# # 04 Results Summary
#
# Goal:
#
# Create final figures and tables.
#
# Questions:
#
# - Which model wins most often?
# - Distribution of Hurst exponents?
# - Relationship between skill level and Hurst?
# - Cross-player comparison
#
# Produces publication-ready plots.

# %%
from pathlib import Path
import sys

import pandas as pd
from IPython.display import display

ROOT = Path.cwd()
if not (ROOT / "data" / "processed").exists():
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

processed_dir = ROOT / "data" / "processed"

files = {
    "model_comparison": processed_dir / "model_comparison.csv",
    "fit_parameters": processed_dir / "fit_parameters.csv",
    "residuals": processed_dir / "residuals.csv",
    "hurst_results": processed_dir / "hurst_results.csv",
}

for name, path in files.items():
    print(f"{name}: {path}")
    if path.exists():
        display(pd.read_csv(path).head())

# %% [markdown]
# ## Publication Figures
#
# Use the fitted model and Hurst outputs to create final report-ready plots.
